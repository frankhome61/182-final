# %%
import glob, os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Image Loading

# %%
########## TensorFlow Preprocessing ########
def load_and_preprocess_image_tensor(path, target_shape):
    """
    Loads and image from PATH and returns a EagerTensor 
    shape: (H, W, C)
    dtype: float32
    """
    image = tf.io.read_file(path)
    return preprocess_image_tensor(image, target_shape)

def preprocess_image_tensor(image, target_shape):
    """Resizes given image"""
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.convert_image_dtype(image, dtype=tf.float32) 
    image -= 0.5
    image *= 2
    image = tf.image.resize(image, 
                           target_shape
                          )
    return image


########## Non-TensorFlow Preprocessing ########
############# NOT USING THEM NOW ###############
def load_and_preprocess_image(path):
    image = plt.imread(path) / 255.
    return preprocess_image(image)

def preprocess_image(image):
    image = image - 0.5
    image = image * 2
    return image

def _floats_feature(value):
    return tf.train.Feature(float_list=tf.train.FloatList(value=value.reshape(-1)))

def wrap_bytes(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def featurize_img(img):
    r_channel = _floats_feature(img[0])
    g_channel = _floats_feature(img[1])
    b_channel = _floats_feature(img[2])
    height = tf.train.Feature(int64_list=tf.train.Int64List(value=[img.shape[0]]))
    width = tf.train.Feature(int64_list=tf.train.Int64List(value=[img.shape[1]]))
    return r_channel, g_channel, b_channel, height, width
###########################################

# %% [markdown]
# ### Get Dataset Paths

# %%
def get_data_paths(data_dir):
    path_lst = []
    
    #assert dataset_type == 'train' or dataset_type == 'val', "Please specify either train or validation"
    for file in os.listdir(data_dir):
        if file.endswith(".jpg"):
            path_lst.append(os.path.join(data_dir, file))
    return path_lst

# %% [markdown]
# ### Get TensorFlow Dataloader

# %%
def get_dataloader(path_lst, batch_size, target_size=(400, 400)):
    """Returns a batch dataset of size BATCH_SIZE"""
    process_fn = lambda path: load_and_preprocess_image_tensor(path, target_size)
    
    
    train_data = tf.data.Dataset.from_tensor_slices(
                 (tf.constant(path_lst)))

    return train_data.map(process_fn) \
             .shuffle(buffer_size=10000) \
             .batch(batch_size)

# %% [markdown]
# ## Load Images from path and reshape

# %%
path_lst = get_data_paths('/media/zhanyuan/My Passport/train/style')

# %%
dat = get_dataloader(path_lst, 1, target_size=(400, 400))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7d8e020fbe6e> in <module>
# ----> 1 dat = get_dataloader(path_lst, 1, target_size=(400, 400))
#
# <ipython-input-11-6dc0764a291c> in get_dataloader(path_lst, batch_size, target_size)
#       7                  (tf.constant(path_lst)))
#       8
# ----> 9     return train_data.map(process_fn) \
#      10              .shuffle(buffer_size=10000) \
#      11              .batch(batch_size)
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls)
#    1036     """
#    1037     if num_parallel_calls is None:
# -> 1038       return MapDataset(self, map_func)
#    1039     else:
#    1040       return ParallelMapDataset(self, map_func, num_parallel_calls)
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism)
#    2609
#    2610     wrapped_func = StructuredFunctionWrapper(
# -> 2611         map_func, "Dataset.map()", input_dataset)
#    2612     self._output_classes = wrapped_func.output_classes
#    2613     self._output_shapes = wrapped_func.output_shapes
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, add_to_graph, experimental_nested_dataset_support)
#    1858     self._function = tf_data_structured_function_wrapper
#    1859     if add_to_graph:
# -> 1860       self._function.add_to_graph(ops.get_default_graph())
#    1861     else:
#    1862       # Use the private method that will execute
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/framework/function.py in add_to_graph(self, g)
#     477   def add_to_graph(self, g):
#     478     """Adds this function into the graph g."""
# --> 479     self._create_definition_if_needed()
#     480
#     481     # Adds this function into 'g'.
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/framework/function.py in _create_definition_if_needed(self)
#     333     """Creates the function definition if it's not created yet."""
#     334     with context.graph_mode():
# --> 335       self._create_definition_if_needed_impl()
#     336
#     337   def _create_definition_if_needed_impl(self):
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/framework/function.py in _create_definition_if_needed_impl(self)
#     342     temp_graph = func_graph_from_py_func(
#     343         self._func, self._arg_names, self._arg_types, self._func_name,
# --> 344         self._capture_by_value, self._caller_device)
#     345
#     346     self._extra_inputs = temp_graph.extra_inputs
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/framework/function.py in func_graph_from_py_func(func, arg_names, arg_types, name, capture_by_value, device, colocation_stack, container, collections_ref, arg_shapes)
#     862     # Call func and gather the output tensors.
#     863     with vs.variable_scope("", custom_getter=func_graph.getvar):
# --> 864       outputs = func(*func_graph.inputs)
#     865
#     866     # There is no way of distinguishing between a function not returning
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in tf_data_structured_function_wrapper(*args)
#    1792         nested_args = (nested_args,)
#    1793
# -> 1794       ret = func(*nested_args)
#    1795       # If `func` returns a list of tensors, `nest.flatten()` and
#    1796       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# <ipython-input-11-6dc0764a291c> in <lambda>(path)
#       1 def get_dataloader(path_lst, batch_size, target_size=(400, 400)):
#       2     """Returns a batch dataset of size BATCH_SIZE"""
# ----> 3     process_fn = lambda path: load_and_preprocess_image_tensor(path, target_size)
#       4
#       5
#
# <ipython-input-2-49ddd22dfac2> in load_and_preprocess_image_tensor(path, target_shape)
#       7     """
#       8     image = tf.io.read_file(path)
# ----> 9     return preprocess_image_tensor(image, target_shape)
#      10
#      11 def preprocess_image_tensor(image, target_shape):
#
# <ipython-input-2-49ddd22dfac2> in preprocess_image_tensor(image, target_shape)
#      15     image -= 0.5
#      16     image *= 2
# ---> 17     image = tf.image.resize(image,
#      18                            target_shape
#      19                           )
#
# AttributeError: module 'tensorflow._api.v1.image' has no attribute 'resize'

# %%
dat_iter = iter(dat)

# %%
next_im = next(dat_iter)
next_im = next(dat_iter)
next_im = next(dat_iter)

# %%
import matplotlib.pyplot as plt
plt.imshow(next_im[0])
# Out:
# W0421 16:50:39.787580 4449838528 image.py:656] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
